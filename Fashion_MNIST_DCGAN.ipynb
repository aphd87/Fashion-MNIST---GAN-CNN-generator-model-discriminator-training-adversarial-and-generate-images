# %% [markdown]
# ### DCGAN  on MNIST
#
# DCGAN is a Generative Adversarial Network (GAN) using CNN.
#
# 1. The discriminator learns to discriminate real from fake images.
# 2. The generator tries to fool the discriminator by generating fake images.
# 3. The generator + discriminator form an adversarial network.
# 4. DCGAN trains the discriminator and adversarial networks alternately.
#
# During training, not only the discriminator learns to distinguish real from
# fake images, it also coaches the generator part of the Adversarial network on how
# to improve its ability to generate fake images.

# %%
import tensorflow as tf
import numpy as np
import math
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #### Buiding a Generator Model
#
# Build a model using layers of BatchNorm-ReLU-Conv2DTranpose to generate fake images

# %%
def build_generator(image_size=28, input_size=100):
    
    model = tf.keras.Sequential()

    #Increase dimensions and resize to 3D to feed it to Conv2DTranspose layer
    model.add(tf.keras.layers.Dense(7 * 7 * 128, input_shape=(input_size,)))
    model.add(tf.keras.layers.Reshape((7,7,128)))

    #Use ConvTranspose - 1
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Conv2DTranspose(128, kernel_size=[5,5], strides=2, 
                                              padding='same')) #14,14,128

    #Use ConvTranspose - 2
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Conv2DTranspose(64, kernel_size=[5,5], strides=2, padding='same'))

    #Use ConvTranspose - 3
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Conv2DTranspose(32, kernel_size=[5,5], strides=1, padding='same'))

    #Use ConvTranspose - 4
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Conv2DTranspose(1, kernel_size=[5,5], strides=1, padding='same'))

    #Output layer for Generator
    model.add(tf.keras.layers.Activation('sigmoid'))
    
    return model

# %% [markdown]
# #### Building a Discriminator

# %%
def build_discriminator(data_shape=[28,28,1,]):
    
    model = tf.keras.Sequential()

    #Build the network
    model.add(tf.keras.layers.Conv2D(32, kernel_size=[5,5], strides=2, padding='same' , input_shape=data_shape)) #14,14,32
    model.add(tf.keras.layers.LeakyReLU(alpha=0.2))
    model.add(tf.keras.layers.Conv2D(64, kernel_size=[5,5], strides=2, padding='same')) #7x7x64
    model.add(tf.keras.layers.LeakyReLU(alpha=0.2))
    model.add(tf.keras.layers.Conv2D(128, kernel_size=[5,5], strides=2, padding='same')) #3x3x128
    model.add(tf.keras.layers.LeakyReLU(alpha=0.2))
    model.add(tf.keras.layers.Conv2D(256, kernel_size=[5,5], strides=1, padding='same')) #3x3x256

    #Flatten the output and build an output layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    return model

# %% [markdown]
# #### Building Models for Training

# %%
def build_models():
    
    tf.keras.backend.clear_session()
    
    noise_size = 100
    lr = 2e-4
    decay = 6e-8
    
    #Build Base Discriminator model
    base_discriminator = build_discriminator(data_shape=(28,28,1,))
    
    #Define optimizer and compile model
    discriminator = tf.keras.models.Model(inputs=base_discriminator.inputs, 
                                          outputs=base_discriminator.outputs)
    optimizer = tf.keras.optimizers.RMSprop(lr=lr, decay=decay)
    discriminator.compile(loss='binary_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])
    
    #Build Generator model
    generator = build_generator(image_size=28, input_size=noise_size)
    
    #Build Frozen Discriminator
    frozen_discriminator = tf.keras.models.Model(inputs=base_discriminator.inputs, 
                                          outputs=base_discriminator.outputs)
    #Freeze the weights of discriminator during adversarial training
    frozen_discriminator.trainable = False

    #Build Adversarial model
    #Adversarial = generator + discriminator
    adversarial = tf.keras.models.Model(generator.input, 
                        frozen_discriminator(generator.output))
    
    optimizer = tf.keras.optimizers.RMSprop(lr=lr * 0.5, decay=decay * 0.5)
    adversarial.compile(loss='binary_crossentropy',
                        optimizer=optimizer,
                        metrics=['accuracy'])    
    
    return generator, discriminator, adversarial

# %% [markdown]
# #### Training Discriminator and Adversarial Models

# %%
def train_gan(generator, discriminator, adversarial, noise_size=100):
    
    #Training parameters
    batch_size = 64
    train_steps = 10000
    image_size = 28
    
    # load MNIST dataset
    (train_x, _), (_, _) = tf.keras.datasets.fashion_mnist.load_data()
    
    #Make it 3D dataset - 28x28 to 28x28x1
    train_x = np.reshape(train_x, [-1, image_size, image_size, 1])

    #Standardize data : 0 to 1
    train_x = train_x.astype('float32') / 255
    
    #Input for testing generator at different intervals, we will generate 16 images
    test_noise_input = np.random.uniform(-1.0,1.0, size=[16, noise_size]) #16, 100
    
    #Start training
    for i in range(train_steps):
        
        #Train DISCRIMATOR
        
        #1. Get fake images from Generator
        noise_input = np.random.uniform(-1.0,1.0, size=[batch_size, noise_size])  #64, 100
        fake_images = generator.predict(noise_input) #64, 28, 28, 1
        
        #2. Get real images from training set
        img_indexes = np.random.randint(0, train_x.shape[0], size=batch_size)
        real_images = train_x[img_indexes] #64, 28, 28, 1
        
        #3. Prepare input for training Discriminator
        X = np.concatenate((real_images, fake_images))  #128, 28, 28, 1
        
        #4. Labels for training
        y_real = np.ones((batch_size, 1)) #64,1 -> 1
        y_fake = np.zeros((batch_size, 1)) #64,1 -> 0
        y = np.concatenate((y_real, y_fake)) #128, 1
        
        #5. Train Discriminator
        #discriminator.fit(x,y, epochs=1, batch_size=128)
        d_loss, d_acc = discriminator.train_on_batch(X, y)
        
        #Train ADVERSARIAL Network
        
        #1. Prepare input - create a new batch of noise
        X = np.random.uniform(-1.0,1.0, size=[batch_size, noise_size]) #64, 100
        
        #2. Prepare labels - training Adversarial network to lie :) - All 1s
        y = np.ones((batch_size, 1))
        
        #3. Train - Pls note Discrimator is not getting trained here
        a_loss, a_acc = adversarial.train_on_batch(X, y)
        
        if i % 100 == 0:
            #Print loss and Accuracy for both networks
            print("%s [Discriminator loss: %f, acc: %f, Adversarial loss: %f, acc: %f]" % (i, d_loss, d_acc, a_loss, a_acc) )
        
        #Save generated images to see how well Generator is doing
        if (i+1) % 500 == 0:
            
            #Generate 16 images
            fake_images = generator.predict(test_noise_input)
            
            #Display images
            plot_images(fake_images, i+1)
            
    #Save Generator model
    generator.save('mnist_generator_dcgan.h5')

# %% [markdown]
# #### Save generator images

# %%
def plot_images(fake_images, step):
    
    plt.figure(figsize=(2.5,2.5))
    num_images = fake_images.shape[0]
    
    image_size = fake_images.shape[1]
    rows = int(math.sqrt(fake_images.shape[0]))
    
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(fake_images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.show()

# %% [markdown]
# ### Start GAN Training

# %%
G, D, A = build_models()
# Out:
# C:\Users\19144\AppData\Roaming\Python\Python39\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:140: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
G.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 6272)              633472
#
#  reshape (Reshape)           (None, 7, 7, 128)         0
#
#  batch_normalization (BatchN  (None, 7, 7, 128)        512
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 128)         0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      409728
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 64)       204864
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 32)       51232
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 28, 28, 32)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        801
#  ranspose)
#
#  activation_4 (Activation)   (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1,301,505
# Trainable params: 1,300,801
# Non-trainable params: 704
# _________________________________________________________________

# %%
D.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 14, 14, 32)        832
#
#  leaky_re_lu (LeakyReLU)     (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          51264
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 7, 7, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         204928
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4, 4, 128)         0
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         819456
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1)                 4097
#
# =================================================================
# Total params: 1,080,577
# Trainable params: 0
# Non-trainable params: 1,080,577
# _________________________________________________________________

# %%
A.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1_input (InputLayer)  [(None, 100)]             0
#
#  dense_1 (Dense)             (None, 6272)              633472
#
#  reshape (Reshape)           (None, 7, 7, 128)         0
#
#  batch_normalization (BatchN  (None, 7, 7, 128)        512
#  ormalization)
#
#  activation (Activation)     (None, 7, 7, 128)         0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 128)      409728
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 14, 14, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 64)       204864
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 28, 28, 32)       51232
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 28, 28, 32)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 28, 28, 1)        801
#  ranspose)
#
#  activation_4 (Activation)   (None, 28, 28, 1)         0
#
#  model_1 (Functional)        (None, 1)                 1080577
#
# =================================================================
# Total params: 2,382,082
# Trainable params: 1,300,801
# Non-trainable params: 1,081,281
# _________________________________________________________________

# %%
train_gan(G, D, A)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# 2/2 [==============================] - 1s 225ms/step
# 0 [Discriminator loss: 0.695119, acc: 0.500000, Adversarial loss: 0.805055, acc: 0.000000]
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 92ms/step
# 100 [Discriminator loss: 0.005925, acc: 1.000000, Adversarial loss: 0.000000, acc: 1.000000]
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 102ms/step
# 200 [Discriminator loss: 0.000209, acc: 1.000000, Adversarial loss: 0.000000, acc: 1.000000]
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 218ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 106ms/step
# 300 [Discriminator loss: 0.000112, acc: 1.000000, Adversarial loss: 0.000000, acc: 1.000000]
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 210ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 240ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 133ms/step
# 400 [Discriminator loss: 0.000424, acc: 1.000000, Adversarial loss: 0.000000, acc: 1.000000]
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 463ms/step
# 2/2 [==============================] - 0s 104ms/step
# 500 [Discriminator loss: 0.797680, acc: 0.523438, Adversarial loss: 2.349911, acc: 0.015625]
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 69ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 210ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 205ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 83ms/step
# 600 [Discriminator loss: 0.474654, acc: 0.812500, Adversarial loss: 0.608015, acc: 0.640625]
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 1s 199ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 162ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 113ms/step
# 700 [Discriminator loss: 0.525239, acc: 0.734375, Adversarial loss: 0.620161, acc: 0.609375]
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 81ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 96ms/step
# 800 [Discriminator loss: 0.527442, acc: 0.773438, Adversarial loss: 1.026618, acc: 0.281250]
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 82ms/step
# ...
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 264ms/step
# 2/2 [==============================] - 0s 245ms/step
# 2/2 [==============================] - 0s 234ms/step
# 2/2 [==============================] - 1s 239ms/step
# 2/2 [==============================] - 1s 249ms/step
# 2/2 [==============================] - 1s 312ms/step
# 2/2 [==============================] - 1s 278ms/step
# 2/2 [==============================] - 1s 291ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 282ms/step
# 7200 [Discriminator loss: 0.441476, acc: 0.765625, Adversarial loss: 0.978567, acc: 0.328125]
# 2/2 [==============================] - 1s 245ms/step
# 2/2 [==============================] - 0s 237ms/step
# 2/2 [==============================] - 1s 236ms/step
# 2/2 [==============================] - 1s 274ms/step
# 2/2 [==============================] - 1s 258ms/step
# 2/2 [==============================] - 1s 260ms/step
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 265ms/step
# 2/2 [==============================] - 1s 263ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 0s 234ms/step
# 2/2 [==============================] - 1s 238ms/step
# 2/2 [==============================] - 1s 246ms/step
# 2/2 [==============================] - 1s 295ms/step
# 2/2 [==============================] - 1s 330ms/step
# 2/2 [==============================] - 1s 376ms/step
# 2/2 [==============================] - 1s 409ms/step
# 2/2 [==============================] - 1s 357ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 1s 285ms/step
# 2/2 [==============================] - 1s 346ms/step
# 2/2 [==============================] - 1s 241ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 273ms/step
# 2/2 [==============================] - 1s 272ms/step
# 2/2 [==============================] - 1s 268ms/step
# 2/2 [==============================] - 1s 309ms/step
# 2/2 [==============================] - 1s 326ms/step
# 2/2 [==============================] - 1s 249ms/step
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 285ms/step
# 2/2 [==============================] - 1s 251ms/step
# 2/2 [==============================] - 1s 334ms/step
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 301ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 279ms/step
# 2/2 [==============================] - 1s 268ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 319ms/step
# 2/2 [==============================] - 1s 311ms/step
# 2/2 [==============================] - 1s 263ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 276ms/step
# 2/2 [==============================] - 1s 231ms/step
# 2/2 [==============================] - 1s 278ms/step
# 2/2 [==============================] - 1s 292ms/step
# 2/2 [==============================] - 1s 310ms/step
# 2/2 [==============================] - 1s 325ms/step
# 2/2 [==============================] - 1s 355ms/step
# 2/2 [==============================] - 1s 241ms/step
# 2/2 [==============================] - 1s 276ms/step
# 2/2 [==============================] - 1s 285ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 0s 236ms/step
# 2/2 [==============================] - 1s 236ms/step
# 2/2 [==============================] - 1s 258ms/step
# 2/2 [==============================] - 1s 310ms/step
# 2/2 [==============================] - 1s 333ms/step
# 2/2 [==============================] - 1s 296ms/step
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 299ms/step
# 2/2 [==============================] - 0s 243ms/step
# 2/2 [==============================] - 1s 275ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 1s 297ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 308ms/step
# 2/2 [==============================] - 1s 333ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 0s 239ms/step
# 2/2 [==============================] - 0s 213ms/step
# 2/2 [==============================] - 1s 312ms/step
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 304ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 311ms/step
# 2/2 [==============================] - 1s 307ms/step
# 2/2 [==============================] - 1s 258ms/step
# 2/2 [==============================] - 1s 260ms/step
# 2/2 [==============================] - 1s 307ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 300ms/step
# 2/2 [==============================] - 1s 366ms/step
# 2/2 [==============================] - 1s 335ms/step
# 2/2 [==============================] - 1s 315ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 258ms/step
# 2/2 [==============================] - 1s 321ms/step
# 7300 [Discriminator loss: 0.467553, acc: 0.789062, Adversarial loss: 1.091097, acc: 0.250000]
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 356ms/step
# 2/2 [==============================] - 1s 291ms/step
# 2/2 [==============================] - 1s 338ms/step
# 2/2 [==============================] - 1s 330ms/step
# 2/2 [==============================] - 1s 298ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 307ms/step
# 2/2 [==============================] - 1s 273ms/step
# 2/2 [==============================] - 1s 298ms/step
# 2/2 [==============================] - 1s 342ms/step
# 2/2 [==============================] - 1s 308ms/step
# 2/2 [==============================] - 1s 354ms/step
# 2/2 [==============================] - 1s 318ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 264ms/step
# 2/2 [==============================] - 1s 279ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 259ms/step
# 2/2 [==============================] - 1s 369ms/step
# 2/2 [==============================] - 1s 266ms/step
# 2/2 [==============================] - 1s 333ms/step
# 2/2 [==============================] - 1s 338ms/step
# 2/2 [==============================] - 1s 302ms/step
# 2/2 [==============================] - 1s 333ms/step
# 2/2 [==============================] - 1s 284ms/step
# 2/2 [==============================] - 1s 318ms/step
# 2/2 [==============================] - 1s 259ms/step
# 2/2 [==============================] - 1s 315ms/step
# 2/2 [==============================] - 1s 313ms/step
# 2/2 [==============================] - 1s 358ms/step
# 2/2 [==============================] - 1s 337ms/step
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 307ms/step
# 2/2 [==============================] - 1s 366ms/step
# 2/2 [==============================] - 1s 302ms/step
# 2/2 [==============================] - 1s 390ms/step
# 2/2 [==============================] - 1s 334ms/step
# 2/2 [==============================] - 1s 400ms/step
# 2/2 [==============================] - 1s 404ms/step
# 2/2 [==============================] - 1s 376ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 287ms/step
# 2/2 [==============================] - 1s 363ms/step
# 2/2 [==============================] - 1s 343ms/step
# 2/2 [==============================] - 1s 296ms/step
# 2/2 [==============================] - 1s 338ms/step
# 2/2 [==============================] - 1s 314ms/step
# 2/2 [==============================] - 1s 400ms/step
# 2/2 [==============================] - 1s 317ms/step
# 2/2 [==============================] - 1s 389ms/step
# 2/2 [==============================] - 1s 396ms/step
# 2/2 [==============================] - 1s 317ms/step
# 2/2 [==============================] - 1s 304ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 299ms/step
# 2/2 [==============================] - 1s 284ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 286ms/step
# 2/2 [==============================] - 1s 294ms/step
# 2/2 [==============================] - 1s 286ms/step
# 2/2 [==============================] - 1s 294ms/step
# 2/2 [==============================] - 1s 325ms/step
# 2/2 [==============================] - 1s 270ms/step
# 2/2 [==============================] - 1s 266ms/step
# 2/2 [==============================] - 1s 264ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 316ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 252ms/step
# 2/2 [==============================] - 1s 256ms/step
# 2/2 [==============================] - 1s 255ms/step
# 2/2 [==============================] - 1s 302ms/step
# 2/2 [==============================] - 1s 255ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 1s 264ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 1s 295ms/step
# 2/2 [==============================] - 1s 309ms/step
# 2/2 [==============================] - 1s 361ms/step
# 2/2 [==============================] - 1s 325ms/step
# 2/2 [==============================] - 1s 314ms/step
# 2/2 [==============================] - 1s 295ms/step
# 2/2 [==============================] - 1s 294ms/step
# 2/2 [==============================] - 1s 279ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 1s 319ms/step
# 2/2 [==============================] - 1s 263ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 1s 287ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 255ms/step
# 2/2 [==============================] - 1s 273ms/step
# 2/2 [==============================] - 1s 333ms/step
# 2/2 [==============================] - 1s 289ms/step
# 7400 [Discriminator loss: 0.513513, acc: 0.679688, Adversarial loss: 0.983812, acc: 0.375000]
# 2/2 [==============================] - 1s 292ms/step
# 2/2 [==============================] - 1s 283ms/step
# 2/2 [==============================] - 1s 279ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 290ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 1s 287ms/step
# 2/2 [==============================] - 1s 327ms/step
# 2/2 [==============================] - 1s 271ms/step
# 2/2 [==============================] - 1s 278ms/step
# 2/2 [==============================] - 1s 272ms/step
# 2/2 [==============================] - 1s 294ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 359ms/step
# 2/2 [==============================] - 1s 301ms/step
# 2/2 [==============================] - 1s 285ms/step
# 2/2 [==============================] - 1s 327ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 250ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 1s 297ms/step
# 2/2 [==============================] - 1s 259ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 1s 254ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 251ms/step
# 2/2 [==============================] - 1s 252ms/step
# 2/2 [==============================] - 1s 255ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 316ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 298ms/step
# 2/2 [==============================] - 1s 354ms/step
# 2/2 [==============================] - 1s 312ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 297ms/step
# 2/2 [==============================] - 1s 298ms/step
# 2/2 [==============================] - 1s 340ms/step
# 2/2 [==============================] - 1s 292ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 276ms/step
# 2/2 [==============================] - 1s 266ms/step
# 2/2 [==============================] - 1s 265ms/step
# 2/2 [==============================] - 1s 291ms/step
# 2/2 [==============================] - 1s 343ms/step
# 2/2 [==============================] - 1s 353ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 259ms/step
# 2/2 [==============================] - 1s 315ms/step
# 2/2 [==============================] - 1s 250ms/step
# 2/2 [==============================] - 1s 293ms/step
# 2/2 [==============================] - 1s 250ms/step
# 2/2 [==============================] - 1s 252ms/step
# 2/2 [==============================] - 1s 250ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 320ms/step
# 2/2 [==============================] - 1s 338ms/step
# 2/2 [==============================] - 1s 375ms/step
# 2/2 [==============================] - 1s 349ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 1s 315ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 300ms/step
# 2/2 [==============================] - 1s 257ms/step
# 2/2 [==============================] - 1s 316ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 286ms/step
# 2/2 [==============================] - 1s 302ms/step
# 2/2 [==============================] - 1s 314ms/step
# 2/2 [==============================] - 1s 346ms/step
# 2/2 [==============================] - 1s 344ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 1s 278ms/step
# 2/2 [==============================] - 1s 312ms/step
# 2/2 [==============================] - 1s 256ms/step
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 279ms/step
# 2/2 [==============================] - 1s 256ms/step
# 2/2 [==============================] - 1s 258ms/step
# 2/2 [==============================] - 1s 267ms/step
# 2/2 [==============================] - 1s 306ms/step
# 2/2 [==============================] - 1s 303ms/step

# %%
def generate_images():

    test_noise_input = np.random.uniform(-1.0,1.0, size=[16, 100]) #16, 100
    
    #Generate 16 images
    fake_images = G.predict(test_noise_input)
    
    #Display images
    plot_images(fake_images, None)

# %%
generate_images()
